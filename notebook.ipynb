# %%
import numpy as np
import pandas as pd

print("Hello, your Jupyter Notebook is working!")

# Create a small Dataframe
df = pd.DataFrame({
    "A": [1, 2, 3],
    "B": [4, 5, 6]
}

)
# Out:
# Hello, your Jupyter Notebook is working!
